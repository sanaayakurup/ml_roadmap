# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# %%
#pie chart 
slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
plt.pie(slices, labels=labels,autopct='%1.1f%%')
plt.title('my pie')
# Out:
# Text(0.5, 1.0, 'my pie')

# %%
##stack charts 
minutes = [1, 2, 3, 4, 5, 6, 7, 8, 9]

player1 = [8, 6, 5, 5, 4, 2, 1, 1, 0]
player2 = [0, 1, 2, 2, 2, 4, 4, 4, 4]
player3 = [0, 1, 1, 1, 2, 2, 3, 3, 4]
labels=['player1','p2','p3']
#stack chart-indi contri+total contri in a single chartt
plt.stackplot(minutes,player1,player2,player3,labels=labels)
plt.xlabel('Players contri')
plt.ylabel('Minutes')
plt.title('total goals')
plt.legend()

# %%
#linbe chart reading
#https://www.youtube.com/watch?v=x0Uguu7gqgk
data=pd.read_csv('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Matplotlib/05-Fill_Betweens/data.csv')
data.head()
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791
# 2   20     18012   20000       18942
# 3   21     20628   24744       21780
# 4   22     25206   30500       25704

# %%
plt.plot(data['Age'],data['All_Devs'],label='all_dev')
plt.plot(data['Age'],data['Python'],label='p_Dev',linestyle='--')
overall_median=57287
plt.fill_between(data['Age'],data['Python'],overall_median,where=(data['Python']>overall_median),alpha=0.25,interpolate=True,label='above avg')
plt.fill_between(data['Age'],data['Python'],overall_median,where=(data['Python']<=overall_median),alpha=0.25,interpolate=True,label='below avg')
plt.legend()
plt.xlabel('Age')
plt.ylabel('Sal')
plt.title('Age vs median sal')
# Out:
# Text(0.5, 1.0, 'Age vs median sal')

# %%
plt.hist(data['Age'],bins=8,edgecolor='black') #https://www.youtube.com/watch?v=XDv6T4a0RNc
# Out:
# (array([5., 5., 4., 5., 5., 4., 5., 5.]),
#  array([18.   , 22.625, 27.25 , 31.875, 36.5  , 41.125, 45.75 , 50.375,
#         55.   ]),
#  <a list of 8 Patch objects>)

# %%
#plot on log scale 
plt.hist(data['Age'],bins=8,edgecolor='black',log=True)
# Out:
# (array([5., 5., 4., 5., 5., 4., 5., 5.]),
#  array([18.   , 22.625, 27.25 , 31.875, 36.5  , 41.125, 45.75 , 50.375,
#         55.   ]),
#  <a list of 8 Patch objects>)

# %%
median_age=20
plt.hist(data['Age'],bins=3,edgecolor='black')
plt.axvline(median_age,color='red')#axis vertical line

# %%
##scater plots 
plt.scatter(data['Age'],data['All_Devs'])
