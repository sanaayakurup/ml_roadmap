# %%
#pandas playlist campusx
import numpy as np
import pandas as pd
data=pd.read_csv('matches - matches.csv')

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#important functions and attributes
data.head(10)
data.tail(2)
# Out:
#       id  season       city        date                team1  \
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2          toss_winner toss_decision  result  \
# 634          Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
# 635  Royal Challengers Bangalore  Sunrisers Hyderabad           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 634           0  Sunrisers Hyderabad            0               4
# 635           0  Sunrisers Hyderabad            8               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# 634       DA Warner       Feroz Shah Kotla        M Erasmus     CK Nandan
# 635     BCJ Cutting  M Chinnaswamy Stadium  HDPK Dharmasena  BNJ Oxenford
#
#      umpire3
# 634      NaN
# 635      NaN

# %%
data.shape #rows and columns
# Out:
# (636, 18)

# %%
data.info() #data about type of vars
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe() #statistical measures
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
##featching columns and rows using iloc and loc
#want to fetch winner col
data['winner'] #series data
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
#fetch multiple cols
data[['winner', 'team1','team2']]
# Out:
#                           winner                        team1  \
# 0            Sunrisers Hyderabad          Sunrisers Hyderabad
# 1         Rising Pune Supergiant               Mumbai Indians
# 2          Kolkata Knight Riders                Gujarat Lions
# 3                Kings XI Punjab       Rising Pune Supergiant
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 631  Royal Challengers Bangalore             Delhi Daredevils
# 632  Royal Challengers Bangalore                Gujarat Lions
# 633          Sunrisers Hyderabad          Sunrisers Hyderabad
# 634          Sunrisers Hyderabad                Gujarat Lions
# 635          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                            team2
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4               Delhi Daredevils
# ...

# %%
data.iloc[0,1] #index location -0 row, 1 col
data.iloc[:,[1,4,5]] #all rows, 1,4,5
# Out:
#      season                        team1                        team2
# 0      2017          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1      2017               Mumbai Indians       Rising Pune Supergiant
# 2      2017                Gujarat Lions        Kolkata Knight Riders
# 3      2017       Rising Pune Supergiant              Kings XI Punjab
# 4      2017  Royal Challengers Bangalore             Delhi Daredevils
# ..      ...                          ...                          ...
# 631    2016             Delhi Daredevils  Royal Challengers Bangalore
# 632    2016                Gujarat Lions  Royal Challengers Bangalore
# 633    2016          Sunrisers Hyderabad        Kolkata Knight Riders
# 634    2016                Gujarat Lions          Sunrisers Hyderabad
# 635    2016          Sunrisers Hyderabad  Royal Challengers Bangalore
#
# [636 rows x 3 columns]

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#filtering on df
#filter hyd city=hyd matches 
data[(data.city=='Hyderabad') & (data.season==2017)]
# Out:
#     id  season       city        date                   team1  \
# 0    1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 5    6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 18  19    2017  Hyderabad  2017-04-17     Sunrisers Hyderabad
# 20  21    2017  Hyderabad  2017-04-19     Sunrisers Hyderabad
# 35  36    2017  Hyderabad  2017-04-30     Sunrisers Hyderabad
# 42  43    2017  Hyderabad  2017-05-06  Rising Pune Supergiant
# 46  47    2017  Hyderabad  2017-05-08          Mumbai Indians
# 58  59    2017  Hyderabad  2017-05-21          Mumbai Indians
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 5           Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 18              Kings XI Punjab              Kings XI Punjab         field
# 20             Delhi Daredevils          Sunrisers Hyderabad           bat
# ...

# %%
##value counts 
data.season.value_counts()
data.city.value_counts()
# Out:
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Abu Dhabi          7
# Ranchi             7
# Port Elizabeth     7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2
# Name: city, dtype: int64

# %%
#pandas plot function
data.winner.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.toss_decision.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
data.win_by_runs.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.sort_values(['city','date'],ascending=[False,True])
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 315  316    2012  Visakhapatnam  2012-04-09              Deccan Chargers
# 528  529    2015  Visakhapatnam  2015-04-16          Sunrisers Hyderabad
# 530  531    2015  Visakhapatnam  2015-04-18             Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
##drop duplicated 3keeps only unique city 
data.drop_duplicates(subset='city') #keep the first occurance not last
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 48    49    2017          Kanpur  2017-05-10                Gujarat Lions
# 64    65    2008          Jaipur  2008-04-21              Kings XI Punjab
# 66    67    2008         Chennai  2008-04-23          Chennai Super Kings
# ...

# %%
#get season winnders 
data.drop_duplicates(subset='season',keep='last')[['season','winner']].sort_values('season')
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %%
#group by 
data.groupby('season')['win_by_runs'].sum().sort_values(ascending=False)
# Out:
# season
# 2013    1241
# 2011    1098
# 2010     976
# 2012     960
# 2015     850
# 2017     788
# 2009     764
# 2008     705
# 2016     676
# 2014     644
# Name: win_by_runs, dtype: int64

# %%
data.groupby('winner')['win_by_wickets'].mean().sort_values(ascending=False)
# Out:
# winner
# Gujarat Lions                  5.000000
# Kochi Tuskers Kerala           5.000000
# Delhi Daredevils               4.322581
# Rising Pune Supergiants        4.000000
# Royal Challengers Bangalore    3.794521
# Kolkata Knight Riders          3.779221
# Rajasthan Royals               3.698413
# Kings XI Punjab                3.242857
# Rising Pune Supergiant         3.100000
# Pune Warriors                  3.000000
# Mumbai Indians                 2.934783
# Sunrisers Hyderabad            2.785714
# Chennai Super Kings            2.632911
# Deccan Chargers                2.482759
# Name: win_by_wickets, dtype: float64

# %%
##isin fucntion 
l=['Gujarat Lions','Deccan Chargers']
data[data.winner.isin(l)]
# Out:
#       id  season          city        date                        team1  \
# 12    13    2017        Rajkot  2017-04-14       Rising Pune Supergiant
# 22    23    2017       Kolkata  2017-04-21        Kolkata Knight Riders
# 29    30    2017     Bangalore  2017-04-27  Royal Challengers Bangalore
# 45    46    2017    Chandigarh  2017-05-07              Kings XI Punjab
# 71    72    2008        Mumbai  2008-04-27               Mumbai Indians
# 84    85    2008       Chennai  2008-05-06          Chennai Super Kings
# 120  121    2009     Cape Town  2009-04-19        Kolkata Knight Riders
# 123  124    2009     Cape Town  2009-04-22              Deccan Chargers
# 127  128    2009        Durban  2009-04-25              Deccan Chargers
# 130  131    2009        Durban  2009-04-27          Chennai Super Kings
# 146  147    2009     Centurion  2009-05-06              Deccan Chargers
# 154  155    2009     Kimberley  2009-05-11              Deccan Chargers
# ...

# %%
##merge function 
data.merge(data1,right_on, left_on, )

# %%
##pivot_function
data.pivot_table(index='winner',values='win_by_runs',columns='toss_decision',aggfunc='mean')
# Out:
# toss_decision                      bat      field
# winner
# Chennai Super Kings          21.600000  17.482759
# Deccan Chargers              15.500000  13.600000
# Delhi Daredevils              9.571429   8.911765
# Gujarat Lions                 0.000000   0.090909
# Kings XI Punjab               8.150000  13.980000
# Kochi Tuskers Kerala               NaN   3.833333
# Kolkata Knight Riders        11.794118  11.534884
# Mumbai Indians               16.682927  16.627451
# Pune Warriors                 9.333333  18.333333
# Rajasthan Royals             11.933333  14.030303
# Rising Pune Supergiant             NaN  12.300000
# Rising Pune Supergiants       0.000000  17.666667
# Royal Challengers Bangalore  10.038462  19.893617
# Sunrisers Hyderabad           4.062500  15.807692

# %%
#corr function 
data.corr()
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets  \
# id              1.000000  0.471087    0.024281    -0.010263       -0.015510
# season          0.471087  1.000000    0.004170    -0.016815       -0.000708
# dl_applied      0.024281  0.004170    1.000000    -0.010893       -0.011640
# win_by_runs    -0.010263 -0.016815   -0.010893     1.000000       -0.565181
# win_by_wickets -0.015510 -0.000708   -0.011640    -0.565181        1.000000
# umpire3              NaN       NaN         NaN          NaN             NaN
#
#                 umpire3
# id                  NaN
# season              NaN
# dl_applied          NaN
# win_by_runs         NaN
# win_by_wickets      NaN
# umpire3             NaN

# %%
import seaborn as sns
sns.corrplot(data.corr())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24728\2086147897.py in <module>
#       1 import seaborn as sns
# ----> 2 sns.corrplot(data.corr())
#
# AttributeError: module 'seaborn' has no attribute 'corrplot'

# %%
data.rename(columns={'id':'new_id'},inplace=True)

# %%
data.head()
# Out:
#    new_id  season       city        date                        team1  \
# 0       1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1       2    2017       Pune  2017-04-06               Mumbai Indians
# 2       3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3       4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4       5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.set_index('new_id',inplace=True)

# %%
data.head()
# Out:
#         season       city        date                        team1  \
# new_id
# 1         2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2         2017       Pune  2017-04-06               Mumbai Indians
# 3         2017     Rajkot  2017-04-07                Gujarat Lions
# 4         2017     Indore  2017-04-08       Rising Pune Supergiant
# 5         2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                               team2                  toss_winner  \
# new_id
# 1       Royal Challengers Bangalore  Royal Challengers Bangalore
# 2            Rising Pune Supergiant       Rising Pune Supergiant
# 3             Kolkata Knight Riders        Kolkata Knight Riders
# 4                   Kings XI Punjab              Kings XI Punjab
# 5                  Delhi Daredevils  Royal Challengers Bangalore
#
#        toss_decision  result  dl_applied                       winner  \
# new_id
# 1              field  normal           0          Sunrisers Hyderabad
# ...

# %%
data.reset_index(inplace=True)

# %%
data.dropna(how='all')
# Out:
#      new_id  season       city        date                        team1  \
# 0         1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1         2    2017       Pune  2017-04-06               Mumbai Indians
# 2         3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3         4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4         5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..      ...     ...        ...         ...                          ...
# 631     632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632     633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633     634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634     635    2016      Delhi  2016-05-27                Gujarat Lions
# 635     636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
#fillna
data.city.fillna(data.city.mode()[0],inplace=True)

# %%
data.city.isna().sum()
# Out:
# 0
